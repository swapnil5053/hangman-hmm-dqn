# %%
# Import verification for src package
from importlib import reload
try:
    from src import BigramLM, HangmanEnv, greedy_play, DQNAgent
    print('src imports OK:', BigramLM, HangmanEnv, greedy_play, DQNAgent)
except Exception as e:
    print('Import error:', e)

# %%
# %pip install -q -r ../requirements.txt

# %%
import os, sys
sys.path.append('..')
from src.evaluate import run_dqn
# Train a short DQN run for demo; increase episodes (~10000) for full training as time permits.
results = run_dqn('../data/corpus.txt','../data/test_words.txt',episodes=500,lives=6,seed=42,
                   outdir='../plots', epsilon_start=1.0, epsilon_end=0.05, epsilon_decay=0.995, data_dir='../data')
list(results.keys())
