# %%
# Import verification for src package
try:
    from src import BigramLM, HangmanEnv, greedy_play, DQNAgent
    print('src imports OK:', BigramLM, HangmanEnv, greedy_play, DQNAgent)
except Exception as e:
    print('Import error:', e)

# %%
# %pip install -q -r ../requirements.txt

# %%
import sys
sys.path.append('..')
from src.evaluate import run_baseline, generate_report
# Run baseline and generate report (uses plots/ and data/ paths)
metrics = run_baseline('../data/corpus.txt','../data/test_words.txt',n_games=200,lives=6,seed=42,outdir='../plots', data_dir='../data')
generate_report('../plots', baseline_metrics=metrics)
'Report generated'
