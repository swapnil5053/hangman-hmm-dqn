# %% [markdown]
# # 03 DQN Training (Optional)
# Train a simple DQN agent on the Hangman environment.

# %%
# %pip install -q -r ../requirements.txt
import os, sys
sys.path.append('..')
from src.evaluate import run_dqn
res = run_dqn('../data/corpus.txt','../data/test_words.txt',episodes=500,lives=6,seed=42,outdir='../output',epsilon_start=1.0,epsilon_end=0.05,epsilon_decay=0.995)
list(res.keys())
