# %% [markdown]
# # 01 Data & HMM
# This notebook loads the corpus, cleans it, trains the HMM oracle, and visualizes letter stats.

# %%
# %pip install -q -r ../requirements.txt
import os
import sys
sys.path.append('..')
from src.hmm_oracle import HMMOracle
from src.utils import load_corpus, letter_histogram, plot_histogram, ensure_dir
corpus='../data/corpus.txt'
oracle=HMMOracle()
oracle.fit(corpus)
print('Words loaded:', len(oracle.words))
ensure_dir('../output')
plot_histogram(letter_histogram(oracle.words),'Corpus Letter Frequency','../output/corpus_letter_freq.png')
{k:v for k,v in list(letter_histogram(oracle.words).items())[:10]}
