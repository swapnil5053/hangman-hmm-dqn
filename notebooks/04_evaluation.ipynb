# %% [markdown]
# # 04 Evaluation & Report
# Generate plots and the analysis report for submission.

# %%
# %pip install -q -r ../requirements.txt
import os, sys
sys.path.append('..')
from src.evaluate import run_baseline, generate_report
metrics=run_baseline('../data/corpus.txt','../data/test_words.txt',n_games=200,lives=6,seed=42,outdir='../output')
generate_report('../output', baseline_metrics=metrics)
'done'
